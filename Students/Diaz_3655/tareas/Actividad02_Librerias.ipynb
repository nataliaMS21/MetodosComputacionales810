# %% [markdown]
# # Actividad 02: Librerias y modelamiento básico
#
# ### Profesor: Juan Marcos Marín Ramírez
# #### Métodos Computacionales
# ---

# %% [markdown]
# ## 1.
# Una persona conduce una moto con rapidez constante $v_m$, mientras que un policia lo hace con aceleración constante $a_p$ (iniciando desde el reposo). Suponga que ambos movimientos inician en $t=0$, haga una gráfica para el movimiento de la moto y del policia, donde el usuario ingrese la velocidad (moto) y aceleración (policia). Además determine el instante $t$ en el cual se encuentran ambos. Ambos movimientos iniciarán en $x_i = 0$
#
# **Pruebe**: para $v_m$ = 15m/s y $a_p$ = 3 m/s², el tiempo deberia ser 10 s
#
#
# $$x_f = x_i + v_m\cdot t$$
#
# $$x_f = x_i + v_o\cdot t + \frac{1}{2}a_p\cdot t^2$$

# %%
import matplotlib.pyplot as plt
import numpy as np
v=float(input("ingrese la velocidad de la moto"))
a=float(input("ingrese la aceleracion del policia"))
t= np.arange(0,15)
for i in t:
  if v*i==(1/2)*a*i**2 and i != 0:
    print("tiempo en la que se encuentran:",i,"s")
  else:
    continue
plt.plot(t,v*t,"b", label="moto")
plt.plot(t,(1/2)*a*t**2,"r", label="policia")
plt.title("pocision de la moto vs posicion del policia")
plt.xlabel("tiempo (s)")
plt.ylabel("posicion (m)")
plt.legend()
plt.grid()
# Out:
# ingrese la velocidad de la moto15
# ingrese la aceleracion del policia3
# tiempo en la que se encuentran: 10 s

# %% [markdown]
# ---
#
# ##2.
# El potencial Lennard-Jones es un modelo simple que aproxima la interacción entre un par de moléculas neutras. Este está definido como:
#
# $$
# V(r) = 4\epsilon \left[ \left( \frac{\sigma}{r} \right)^{12} - \left( \frac{\sigma}{r} \right)^{6} \right]
# $$
#
# Donde:
# - $V(r)$ es el potencial en función de la distancia interatómica $r$.
# - $\epsilon$ es la profundidad del pozo de potencial, es decir, la energía mínima que describe la interacción entre dos partículas.
# - $\sigma$ es la distancia a la cual el potencial es cero, también conocido como el parámetro de distancia.
# - $r$ es la distancia entre las dos partículas.
#
# a. Escriba una función para encontrar modelar el potencial LJ.
#
#
# b. Usando $\sigma = \epsilon = 1$ demuestre que la distancia de equilibrio $r_m$ es aproximadamente $r_m = 2^{1/16}\sigma$. Para esto realice un gráfico del potencial, especificando los ejes. Trunque la serie en $r_c = 2.5\sigma$.
#
#
# c. Verifique que $r_m = 2^{1/16}\sigma$ se cumple para diferentes valores de $\sigma$, dejando $\epsilon$ constante.

# %%
#a

def potencial(r,e,o):
  v= (4*e*((o/r)**12-(o/r)**6))
  return(v)
#b
e=1
o=1
r=np.linspace(1,2.5*o,500)
plt.plot(r,potencial(r,e,o))
plt.title("potencial LJ")
plt.xlabel("distancia (r)")
plt.ylabel("potencial v(r)")
plt.axvline(x=2**(1/6)*o,color="red")
#c
fig,axs=plt.subplots(2,2)
o=1.05
axs[0,0].plot(r,potencial(r,e,o))
axs[0,0].axvline(x=2**(1/6)*o,color="red")
o=1.1
axs[0,1].plot(r,potencial(r,e,o))
axs[0,1].axvline(x=2**(1/6)*o,color="red")
o=1.15
axs[1,0].plot(r,potencial(r,e,o))
axs[1,0].axvline(x=2**(1/6)*o,color="red")
o=1.2
axs[1,1].plot(r,potencial(r,e,o))
axs[1,1].axvline(x=2**(1/6)*o,color="red")

# %% [markdown]
# ##3.
# El siguiente código exporta tablas html de sitios web
#
# ```python
# import pandas as pd
#
# # Dataset 1
# # URL of the webpage
# url = "https://worldpopulationreview.com/country-rankings/average-height-by-country"
#
# # Read the HTML content
# html_content = pd.read_html(url)
#
# alturas = html_content[0]
#
# # Dataset 2
# # URL of the webpage
# url = "https://worldpopulationreview.com/country-rankings/average-net-worth-by-country"
#
# # Read the HTML content
# html_content = pd.read_html(url)
#
# income = html_content[0]
# ````
#
# El primer dataset muestra las alturas medias de niñ@s de 5, 10, 15 y 19 años.
#
# a. Limpie los datos, eliminando columnas en *(in)* y cambie todos los nombres de las columnas al español.
#
# b. Realice un gráfico de barras, donde se muestre una comparación de la estatura media para niños y niñas en ambas categorias. Esto para los primeros 10 paises con mayor y menor altura, además agregue a Colombia.
#
# c. ¿Existirá una relación entre la riqueza y la altura? Usando el dataset `income`, haga un merge con el dataset `alturas`. Ahora, empleando los datos de altura para los 10 mayores (19 años) y 10 menores (19 años). Realice un gráfico donde relacione la altura media con el GDP y concluya si existe alguna relación.

# %%
import pandas as pd

# Dataset 1
# URL of the webpage
url = "https://worldpopulationreview.com/country-rankings/average-height-by-country"

# Read the HTML content
html_content = pd.read_html(url)

alturas = html_content[0]

# Dataset 2
# URL of the webpage
url = "https://worldpopulationreview.com/country-rankings/average-net-worth-by-country"

# Read the HTML content
html_content = pd.read_html(url)

income = html_content[0]
alturas
#a
h=alturas.drop(columns=["Boys 19 (in)","Girls 19 (in)"])
h.columns=["numero","pais","Altura promedio, niños, 19 años (cm)", "niñas 19 (cm)"]
income.columns=["numero","pais","Riqueza por adulto 2022","GDP por adulto 2022","Riqueza total 2022","Participación en la riqueza mundial 2022"]
h
# Out:
#      numero                    pais  Altura promedio, niños, 19 años (cm)  \
# 0       NaN             Netherlands                                   184
# 1       NaN              Montenegro                                   183
# 2       NaN                 Estonia                                   183
# 3       NaN  Bosnia and Herzegovina                                   182
# 4       NaN                 Iceland                                   182
# ..      ...                     ...                                   ...
# 191     NaN        Papua New Guinea                                   163
# 192     NaN         Solomon Islands                                   163
# 193     NaN                    Laos                                   163
# 194     NaN             Timor-Leste                                   160
# 195     NaN                   Total                                   163
#
#      niñas 19 (cm)
# 0              170
# 1              170
# 2              169
# 3              167
# 4              169
# ..             ...
# 191            157
# 192            157
# 193            153
# 194            153
# 195            151
#
# [196 rows x 4 columns]

# %%
income
# Out:
#      numero           pais Riqueza por adulto 2022 GDP por adulto 2022  \
# 0       NaN    Switzerland                $685,226            $120,431
# 1       NaN     Luxembourg                $585,950            $163,432
# 2       NaN  United States                $551,347            $100,380
# 3       NaN      Hong Kong                $551,194             $57,168
# 4       NaN        Iceland                $498,290            $102,597
# ..      ...            ...                     ...                 ...
# 215     NaN       Anguilla                     NaN             $32,835
# 216     NaN   Cook Islands                     NaN             $29,907
# 217     NaN          Nauru                     NaN             $23,044
# 218     NaN         Tuvalu                     NaN              $7,773
# 219     NaN     Montserrat                     NaN             $23,914
#
#     Riqueza total 2022 Participación en la riqueza mundial 2022
# 0                $4.8T                                     1.1%
# 1                $299B                                     0.1%
# 2              $139.9T                                    30.8%
# 3                $3.5T                                     0.8%
# 4                $129B                                      NaN
# ..                 ...                                      ...
# 215                NaN                                      NaN
# 216                NaN                                      NaN
# 217                NaN                                      NaN
# 218                NaN                                      NaN
# 219                NaN                                      NaN
#
# [220 rows x 6 columns]

# %%
#b
max=h.head(10)
min=h.tail(10)
col=h.loc[h["pais"]=="Colombia"]
alt=pd.concat([max,min,col],axis=0)
plt.figure(figsize=(35,10))
plt.bar(alt["pais"],alt["Altura promedio, niños, 19 años (cm)"], label="niños 19")
plt.bar(alt["pais"],alt["niñas 19 (cm)"], label = "niñas 19")
plt.legend()
plt.grid()
plt.xlabel("paises", size=(50))
plt.ylabel("alturas",size=50)
# Out:
# Text(0, 0.5, 'alturas')

# %%
com=income["GDP por adulto 2022"].str.replace("$"," ")
com=com.str.replace(",",".")
incom=pd.to_numeric(com)
inc=pd.concat([incom,income["pais"]], axis=1)
alt_inc=pd.merge(alt,inc)
alt_inc.sort_values("GDP por adulto 2022")
alt_inc["GDP por adulto 2022"]=alt_inc["GDP por adulto 2022"]*1000
alt_inc
# Out:
#     numero                    pais  Altura promedio, niños, 19 años (cm)  \
# 0      NaN             Netherlands                                   184
# 1      NaN              Montenegro                                   183
# 2      NaN                 Estonia                                   183
# 3      NaN  Bosnia and Herzegovina                                   182
# 4      NaN                 Iceland                                   182
# 5      NaN                 Denmark                                   182
# 6      NaN          Czech Republic                                   181
# 7      NaN                  Latvia                                   181
# 8      NaN                Slovakia                                   181
# 9      NaN                 Ukraine                                   181
# 10     NaN              Bangladesh                                   165
# 11     NaN                   Yemen                                   164
# 12     NaN                   Nepal                                   164
# 13     NaN               Guatemala                                   164
# 14     NaN              Mozambique                                   164
# 15     NaN        Papua New Guinea                                   163
# 16     NaN         Solomon Islands                                   163
# 17     NaN                    Laos                                   163
# 18     NaN             Timor-Leste                                   160
# 19     NaN                Colombia                                   172
#
#     niñas 19 (cm)  GDP por adulto 2022
# 0             170              73996.0
# 1             170              12830.0
# 2             169              37294.0
# 3             167               9702.0
# 4             169             102597.0
# 5             169              87815.0
# 6             168              35203.0
# 7             169              29751.0
# 8             167              26469.0
# 9             167               3928.0
# 10            152               3644.0
# 11            155               1271.0
# 12            152               1912.0
# 13            151               8970.0
# 14            155               1179.0
# 15            157               6097.0
# 16            157               4557.0
# 17            153               2997.0
# 18            153               2779.0
# 19            158               8230.0

# %%
plt.figure(figsize=(20,5))
plt.plot(alt_inc["GDP por adulto 2022"],alt_inc["Altura promedio, niños, 19 años (cm)"], marker="o",linestyle=" ")
plt.xlabel("GDP por adulto ($)")
plt.ylabel("Altura promedio, niños, 19 años (cm)")
# Out:
# Text(0, 0.5, 'Altura promedio, niños, 19 años (cm)')

# %% [markdown]
# dado el histograma si se podria concluir que la altura es proporcional a la riqueza pero hay ciertos datos anomalos, que a pesar de tener gran altura no tienen una gran riqueza, otra cosa a destacar es que no sucede lo contrario pues no hay paises donde tengan buena riqueza pero sean de baja estatura, ademas al parecer si cruzas de los 20 000$ las estaturas no bajan de 180 cm
